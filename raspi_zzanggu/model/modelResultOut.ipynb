# %%
import numpy as np
import getFeature as gf

from tqdm.auto import tqdm

# %%
def modelResult(user_input_audio,user_input_text):
    pred = gf.getOutputs(user_input_audio,user_input_text)
    pred_index = np.argmax(pred) #배열로 나온 각 모델의 4개 클래스 확률 값을 평균화
    emotions_list = ['Angry','Happy','Neutral','Sad']
    return emotions_list[pred_index] #평균화된 값 중 최대인 값에 해당하는 감정을 return

# %%
import pandas as pd
train_path = 'd:/Data2/train/'
test_path = 'd:/Data2/test/'
train_csv = pd.read_csv('./csv/train_csv_9.csv')
test_csv = pd.read_csv('./csv/test_csv_9.csv')

# %%
modelResult(test_path+test_csv.iloc[3690]['path'],test_csv.iloc[3690]['발화문'])
# Out:
# C:\Users\smhrd\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 'Angry'

# %%
test_csv
# Out:
#                         wav_id  \
# 0     5f9a29cdd338b948c4e6b09e
# 1     5f620e492e23c7161accd423
# 2     5f09ab52b140144dfcff1c6f
# 3     5fba1892576e9378b67ac76f
# 4     5fbe2771576e9378b67ad41a
# ...                        ...
# 3688  5f6704fcd338b948c4e6823d
# 3689  5fbb377ccb503578af9ee33e
# 3690  5ece4b949aa8ea0eec53ef1e
# 3691  5f0b2ac2b140144dfcff2740
# 3692  5f636f143bd6941613f6d722
#
#                                                     발화문         감정  감정레이블  \
# 0                                      헐! 나 이벤트에 당첨 되었어  Happiness      3
# 1                                회사가 너무 바빠서 1년만에 휴가를 냈어    Sadness      5
# 2                               몸도 마음도 너무 지쳤어 못 버틸 것 같아    Sadness      5
# 3                              응 근데 너무 꺼림칙해서 내가 버리기가 싫어    Sadness      5
# 4                                      응 내가 제일 갖고싶었던 거야  Happiness      3
# ...                                                 ...        ...    ...
# 3688                           결국은 그렇게 해야지 영화나 실컷 봐야겠어!    Sadness      5
# 3689                            고마워 너 덕분에 그래도 조금 낫다 고마워  Happiness      3
# 3690                        친구랑 약속이 있어서 나왔는데 친구가 오지를 않아      Angry      0
# 3691  남자친구랑 사귀면서 만든 추억이 너무 많아서 남자친구를 잊어버릴려면 시간이 많이 걸...    Sadness      5
# 3692                                      너무 실망스럽고 화가 나      Angry      0
#
#       Angry  Happiness  Neutral  Sadness                          path
# 0         0          1        0        0  5f9a29cdd338b948c4e6b09e.wav
# 1         0          0        0        1  5f620e492e23c7161accd423.wav
# 2         0          0        0        1  5f09ab52b140144dfcff1c6f.wav
# 3         0          0        0        1  5fba1892576e9378b67ac76f.wav
# 4         0          1        0        0  5fbe2771576e9378b67ad41a.wav
# ...     ...        ...      ...      ...                           ...
# 3688      0          0        0        1  5f6704fcd338b948c4e6823d.wav
# 3689      0          1        0        0  5fbb377ccb503578af9ee33e.wav
# 3690      1          0        0        0  5ece4b949aa8ea0eec53ef1e.wav
# 3691      0          0        0        1  5f0b2ac2b140144dfcff2740.wav
# 3692      1          0        0        0  5f636f143bd6941613f6d722.wav
#
# [3693 rows x 9 columns]
